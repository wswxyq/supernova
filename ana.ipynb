# %%
import numpy as np
import matplotlib.pyplot as plt
# image size
z_size = 896
xy_size = 384

# %%
a=np.load('fd-1kpc-9.6sm-0-overlaid.csv/npy0_reduced/1150.npz')
plt.figure(figsize=(10,10))
plt.imshow(a['imxz'].T, cmap='jet')
plt.show()
plt.figure(figsize=(10,10))
plt.imshow(a['imyz'].T, cmap='jet')
plt.show()
print(a['imxz'].shape)
# Out:
# (448, 384)

# %%
plt.hist(a['imxz'][a['imxz']!=0].flatten()/4096, bins=np.linspace(0,1,100))
plt.show()

# %%
a['imxz'].max()
# Out:
# 3866

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.figure(figsize=(10,10))

bkg=np.load('fd-1kpc-9.6sm-0-overlaid.csv/bkg_reduced_0/1067.npz')
tot=np.load('fd-1kpc-9.6sm-0-overlaid.csv/npy0_reduced/1067.npz')
plt.imshow(tot['imxz']-bkg['imxz'])
plt.show()
plt.figure(figsize=(10,10))
plt.imshow(tot['imyz'])
plt.show()
plt.figure(figsize=(10,10))
plt.imshow(bkg['imyz'])
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.figure(figsize=(10,10))

bkg=np.load('fd-1kpc-9.6sm-0-overlaid.csv/bkg_reduced_0/1068.npz')
tot=np.load('fd-1kpc-9.6sm-0-overlaid.csv/npy0_reduced/1068.npz')
plt.imshow(tot['imxz']-bkg['imxz'])
plt.show()
plt.figure(figsize=(10,10))
plt.imshow(tot['imyz'])
plt.show()
plt.figure(figsize=(10,10))
plt.imshow(bkg['imyz'])
plt.show()

# %%
plt.hist((tot['imxz']).flatten(), bins=np.linspace(0.01,2000,100))
plt.show()

# %%
plt.hist((tot['imxz']-bkg['imxz']).flatten(), bins=np.linspace(0.01,2000,100))
plt.show()

# %%
txt=np.loadtxt('fd-1kpc-9.6sm-0-overlaid.csv/csv0/1065.txt')

# %%
txt[:, 4].shape
# Out:
# (403054,)

# %%
txt=np.loadtxt('fd-1kpc-9.6sm-0-overlaid.csv/csv0/106.txt')
(txt[:, 2].max(), txt[:, 2].min())
# Out:
# (5021356.0, -29470.0)

# %%
plt.hist(txt[:, 2])
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
a=np.load('fd-1kpc-9.6sm-0-overlaid.csv/npy0_reduced_time/1300.npz')
plt.figure(figsize=(10,10))
plt.imshow(np.multiply(a['imxz'][0,:,:],(a['imxz'][1,:,:]<-0.49)))
plt.show()

# %%
plt.figure(figsize=(10,10))
plt.imshow(np.multiply(a['imxz'][0,:,:],(a['imxz'][1,:,:]>-0.4)))
plt.show()

# %%
a['imxz'][1, :, :].min(), a['imxz'][1, :, :].max()
# Out:
# (-0.5057834, 0.504264)

# %%
a=np.load('fd-1kpc-9.6sm-0-overlaid.csv/npy0_reduced/100.npz')
plt.figure(figsize=(10,10))
plt.imshow(a['imxz'][ :, :]/4096)

# %%
import numpy as np
import matplotlib.pyplot as plt
a=np.loadtxt('fd-1kpc-9.6sm-0-overlaid.csv/csv0/1112.txt')

# %%
z_size = 448
xy_size = 384
def image_gen(event):
    """
    generate npy from event
    """
    #print(event)
    imgxz=np.zeros((z_size, xy_size), dtype=int)
    imgyz=np.zeros((z_size, xy_size), dtype=int)

    for i in range(event.shape[0]):
        if event[i,0]%2 == 0:
            imgxz[int(event[i,0]/2), int(event[i, 1])] = event[i, 3]
        else:
            imgyz[int((event[i, 0]-1)/2), int(event[i, 1])] = event[i, 3]
    return imgxz, imgyz, event[:, 4].max()

# %%
b=a[a[:, 2].argsort()]
c=b[331200:331400, :]
print(c.shape[0], 'hits')
imxz, imyz, max_val = image_gen(c)
plt.figure(figsize=(10,10))
plt.imshow(imxz.T, cmap='jet')
plt.title('supernova neutrino number: '+str(c[:, 4].sum())+'\n time window:'+str((c[-1, 2]-c[0, 2]))+'ns', fontsize=20)
plt.show()
plt.figure(figsize=(10,10))
plt.imshow(imyz.T, cmap='jet')
plt.title('supernova neutrino number: '+str(c[:, 4].sum())+'\n time window:'+str((c[-1, 2]-c[0, 2]))+'ms', fontsize=20)
plt.show()
# Out:
# 200 hits

# %%
b=a[a[:, 2].argsort()]
c=b[330000:340000, :]
print(c.shape[0], 'hits')
imxz, imyz, max_val = image_gen(c)
plt.figure(figsize=(10,10))
plt.imshow(imxz.T, cmap='jet')
plt.title('supernova neutrino number: '+str(c[:, 4].sum())+'\n time window:'+str((c[-1, 2]-c[0, 2]))+'ns', fontsize=20)
plt.show()
plt.figure(figsize=(10,10))
plt.imshow(imyz.T, cmap='jet')
plt.title('supernova neutrino number: '+str(c[:, 4].sum())+'\n time window:'+str((c[-1, 2]-c[0, 2]))+'ms', fontsize=20)
plt.show()
# Out:
# 10000 hits

# %%
imxz, imyz, max_val = image_gen(c[np.where(c[:, 4]==1)])
plt.figure(figsize=(10,10))
plt.imshow(imxz.T, cmap='jet')
plt.show()
plt.figure(figsize=(10,10))
plt.imshow(imyz.T, cmap='jet')
plt.show()

# %%
imyz.max(), imyz.min()
# Out:
# (538, 0)

# %%
c[np.where(c[:, 4]==1)]
# Out:
# array([[7.290000e+02, 2.430000e+02, 4.152016e+06, 1.190000e+02,
#         1.000000e+00],
#        [7.310000e+02, 2.470000e+02, 4.177496e+06, 6.300000e+01,
#         1.000000e+00],
#        [2.760000e+02, 3.350000e+02, 4.236348e+06, 1.750000e+02,
#         1.000000e+00],
#        [2.770000e+02, 8.700000e+01, 4.236440e+06, 5.380000e+02,
#         1.000000e+00]])

# %%
import numpy as np
a=np.load('fd-1kpc-9.6sm-0-overlaid.csv/npz_subevents/1003_3.npz')

# %%
a['sig']
# Out:
# array(2)

# %%
np.sum(a[:, 4])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-9e8c1f70d6c9> in <module>
# ----> 1 np.sum(a[:, 4])
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\lib\npyio.py in __getitem__(self, key)
#     258                 return self.zip.read(key)
#     259         else:
# --> 260             raise KeyError("%s is not a file in the archive" % key)
#     261
#     262
#
# TypeError: not all arguments converted during string formatting
